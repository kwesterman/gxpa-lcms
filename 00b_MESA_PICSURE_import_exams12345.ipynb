# %%
# Requires R 3.4 or later
### Uncomment this code if you are not using the PIC-SURE environment in *BDC-Seven Bridges*, or if you do not have all the necessary dependencies installed.
#install.packages("devtools")

Sys.setenv(TAR = "/bin/tar")
options(unzip = "internal")
devtools::install_github("hms-dbmi/pic-sure-r-adapter-hpds", ref="main", force=T, quiet=FALSE)
library(dplyr)

token <- "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJMT05HX1RFUk1fVE9LRU58ZmVuY2V8NzExOSIsIm5hbWUiOiJQQVVMLkhBTlNPTiIsImVtYWlsIjoiUEFVTC5IQU5TT04iLCJqdGkiOiJ3aGF0ZXZlciIsImlhdCI6MTczNDAyNzY2MywiaXNzIjoiZWR1LmhhcnZhcmQuaG1zLmRibWkucHNhbWEiLCJleHAiOjE3MzY2MTk2NjN9.v0GaTdEL1QZxK2oE5HKKbCGN3QT9u3ZCMl5lPhaN7Wg"

session <- picsure::bdc.initializeSession("https://picsure.biodatacatalyst.nhlbi.nih.gov/picsure", token)
session <- picsure::bdc.setResource(session = session, resourceName = "AUTH")

#queryID <- "709118f7-fecb-4ce7-85f2-b3a186456371"
#queryID <- "78d318b2-6968-477e-a0aa-13ffefbe99e9" # With sidnos this time...
queryID <- "b10e5081-7483-4ef8-84bc-7ac2d9a98b3d" # MESA Air with sidnos this time
results <- picsure::getResultByQueryUUID(session, queryID)
head(results) # View top 5 rows of dataframe
# Out:
# ...
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpPZyOyQ/remotes8d45ea8a2c/hms-dbmi-pic-sure-r-adapter-hpds-e6cae3c/DESCRIPTION’ ... OK
# * preparing ‘picsure’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted ‘LazyData’ from DESCRIPTION
# * building ‘picsure_0.1.1.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading resources...
#
# Loading user profile...
#
# Loading PIC-SURE dictionary (this may take several minutes)...
#
# Loading genomic annotations...
#
# Initialization complete.
#   patient_id \\_consents\\
# 1 405574     phs000209.c1\tphs001416.c1
# 2 405575     phs000209.c1\tphs001416.c1
# 3 405582     phs000209.c1\tphs001416.c1
# 4 405583     phs000209.c1\tphs001416.c1
# 5 405580     phs000209.c1\tphs001416.c1
# ...

# %%
library(data.table)
fwrite(results,'MESA_Air_hdl1.csv')
system('gsutil cp MESA_Air_hdl1.csv $WORKSPACE_BUCKET/phenotypes')
#fwrite(results, 'MESA_HDL_PA_covars_12345.csv')
#system('gsutil cp MESA_HDL_PA_covars_12345.csv $WORKSPACE_BUCKET/phenotypes')
